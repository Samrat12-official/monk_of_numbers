# %%
import pandas as pd

# %% [markdown]
# # Woking with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql-connector-python
# conda install mysql-connector-python       #do it if needed

# go in the mysql workbench ,in mysql connections copy connection string to clipboard 👉 you will get this 👉 root@localhost:3306
#                                                                                    here root is user name  and local host is host 
# example                   root@127.0.0.1:3306        here root is username and "127.0.0.1" is host

#  so in general user@host : bla bla  

import mysql.connector
import pandas as pd
conn = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='S@mrat7894',  
    database='sounak' 
)# take this from mysql
df = pd.read_sql_query("SELECT * FROM countrylanguage", conn)
# conn.close()  #do it when you want to close the connection
# Out:
# C:\Users\HP User\AppData\Local\Temp\ipykernel_17556\2791569084.py:11: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage", conn)

# %%
df
# Out:
#     LanguageID CountryCode    Language IsOfficial  Percentage
# 0            1         USA     English          T        82.1
# 1            2         USA     Spanish          F        13.5
# 2            3         IND       Hindi          T        44.8
# 3            4         IND     English          F        12.2
# 4            5         FRA      French          T        88.3
# 5            6         USA     English          T        82.1
# 6            7         USA     Spanish          F        13.5
# 7            8         IND       Hindi          T        44.8
# 8            9         IND     English          F        12.2
# 9           10         FRA      French          T        88.3
# 10          11         FRA      German          F         1.2
# 11          12         JPN    Japanese          T        98.5
# 12          13         JPN     English          F         0.4
# 13          14         BRA  Portuguese          T        97.9
# ...

# %%
df1=pd.read_sql_query("select Language from countrylanguage",conn)
# Out:
# C:\Users\HP User\AppData\Local\Temp\ipykernel_17556\1359428747.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1=pd.read_sql_query("select Language from countrylanguage",conn)

# %%
df1
# Out:
#       Language
# 0      English
# 1      Spanish
# 2        Hindi
# 3      English
# 4       French
# 5      English
# 6      Spanish
# 7        Hindi
# 8      English
# 9       French
# 10      German
# 11    Japanese
# 12     English
# 13  Portuguese
# 14     Spanish
# 15     Russian
# 16       Tatar
# 17    Mandarin
# 18   Cantonese
# 19     Spanish
# 20     Nahuatl

# %%
df
# Out:
#     LanguageID CountryCode    Language IsOfficial  Percentage
# 0            1         USA     English          T        82.1
# 1            2         USA     Spanish          F        13.5
# 2            3         IND       Hindi          T        44.8
# 3            4         IND     English          F        12.2
# 4            5         FRA      French          T        88.3
# 5            6         USA     English          T        82.1
# 6            7         USA     Spanish          F        13.5
# 7            8         IND       Hindi          T        44.8
# 8            9         IND     English          F        12.2
# 9           10         FRA      French          T        88.3
# 10          11         FRA      German          F         1.2
# 11          12         JPN    Japanese          T        98.5
# 12          13         JPN     English          F         0.4
# 13          14         BRA  Portuguese          T        97.9
# ...
